# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %%
df=pd.read_csv('Data Sets/Mineral ores round the world.csv')

# %%
df.head()
# Out:
#              site_name  latitude  longitude region        country   state  \
# 0     Lookout Prospect  55.05612 -132.14344    NaN  United States  Alaska
# 1  Lucky Find Prospect  55.52751 -132.68514    NaN  United States  Alaska
# 2  Mccullough Prospect  55.97751 -132.99906    NaN  United States  Alaska
# 3      Lucky Jim Claim  55.52195 -132.68653    NaN  United States  Alaska
# 4   Matilda Occurrence  55.14556 -132.05233    NaN  United States  Alaska
#
#   county com_type commod1       commod2  ... dep_type prod_size    dev_stat  \
# 0    NaN        M  Copper  Gold, Silver  ...      NaN         N  Occurrence
# 1    NaN        M  Copper          Gold  ...      NaN         N  Occurrence
# 2    NaN        M  Copper           NaN  ...      NaN         N  Occurrence
# 3    NaN        M    Gold           NaN  ...      NaN         N  Occurrence
# 4    NaN        M    Gold           NaN  ...      NaN         N  Occurrence
#
# ...

# %%
df.shape
# Out:
# (304632, 22)

# %% [markdown]
# ## Region which most Mineral Sites

# %%
sns.countplot(data=df,x=df['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# **Observation**
# - The South Austrilla has maximum Mineral sites

# %% [markdown]
# ## Country with most Mineral Site

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x=df['country'].head(5000))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation**
# - The **United States** has maximum number of mineral sites

# %% [markdown]
# ## State Wise with most Mineral Site

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=df,x=df['state'].head(5000))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation**
# - The **Alaska State** has maximum Mineral Site

# %% [markdown]
# ## Com Type

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df,x=df['com_type'])
plt.title("Command Type of Mineral Site",fontsize=20)
plt.show()

# %% [markdown]
# **Observation**
# - The Command **M** has maximum mineral

# %% [markdown]
# ## Most types of commod1

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=df,x=df['commod1'].head(500))
plt.title("Command Type1 of Mineral Site",fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation**
# - In Command 1 **Gold** has maximum quantity

# %% [markdown]
# ## Most types of commod2

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=df,x=df['commod2'].head(500))
plt.xticks(rotation=90)
plt.title("Command Type2 of Mineral Site",fontsize=20)
plt.show()

# %% [markdown]
# **Observation**
# - In Command 2 the **Silver** has maximum quantity

# %% [markdown]
# ## Most types of commod3

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=df,x=df['commod3'].head(500))
plt.xticks(rotation=90)
plt.title("Command Type 3 of Mineral Site",fontsize=20)
plt.show()

# %% [markdown]
# **Observation**
# - Commad 3 has **Copper** in maximum quantity

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=df,x=df['oper_type'])
plt.title("Operation Type",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Operation Type')

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=df,x=df['dep_type'].head(5000))
plt.title("Dept Type",fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation**
# - Vein dept is maximum

# %% [markdown]
# ## prod_size

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=df,x=df['prod_size'])
plt.title('Prod Size',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Prod Size')

# %% [markdown]
# **Observation**
# - The **N** has maximum Prod_size

# %% [markdown]
# ## dev_stat

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=df,x=df['dev_stat'])
plt.title("Dev_Stat",fontsize=20)
plt.show()

# %% [markdown]
# ## Most types of Ores

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=df,x=df['ore'].head(200))
plt.title("Most types of Ores",fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Work Type

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df['work_type'])
plt.xticks(rotation=90)
plt.show()

# %%
**Observat
