# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.metrics import davies_bouldin_score, silhouette_score, silhouette_samples
from sklearn.preprocessing import StandardScaler


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("D:/Data-Science/Machine learning Model/Classification/DataSet/iris.csv")

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
x=df.iloc[:,:4] = StandardScaler().fit_transform(df.iloc[:,:4])
# Exploratory Data Analysis
sns.pairplot(df,diag_kind='kde')
sns.pairplot(df, hue="variety", diag_kind= 'kde')

# %% [markdown]
# **Observation**
# - clearly show that 3 cluster are formed

# %%
sse=[]
k_rng=range(1,10)
for k in k_rng:
    km=KMeans(n_clusters=k)
    km.fit(df[['sepal.length',"sepal.width","petal.length","petal.width"]])
    sse.append(km.inertia_)

# %%
plt.xlabel("K")
plt.ylabel("Sum of Squared Error")
plt.plot(k_rng,sse)

# %% [markdown]
# **Observation**
# - the elbow point is 3

# %%
kmeans=KMeans(n_clusters=3,max_iter=1000,n_init=10,init='k-means++',random_state=123).fit(x)
clusters=kmeans.labels_
x["predicated"]=clusters
sns.pairplot(x,hue="predicated")

# %%
sns.pairplot(df, hue="variety", diag_kind= 'kde')

# %%
plt.subplot(1,2,1)
sns.pairplot(x,hue="predicated")
plt.subplot(1,2,2)
sns.pairplot(df, hue="variety", diag_kind= 'kde')
