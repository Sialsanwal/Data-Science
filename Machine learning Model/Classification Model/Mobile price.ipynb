# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Mobile Price.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.head(3)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
#
# [3 rows x 21 columns]

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.blue)
plt.subplot(1,2,2)
df.blue.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.dual_sim)
plt.subplot(1,2,2)
df.dual_sim.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.fc)
plt.subplot(1,2,2)
df.fc.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.three_g)
plt.subplot(1,2,2)
df.three_g.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.four_g)
plt.subplot(1,2,2)
df.four_g.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.talk_time)
plt.subplot(1,2,2)
df.talk_time.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.touch_screen)
plt.subplot(1,2,2)
df.touch_screen.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.wifi)
plt.subplot(1,2,2)
df.wifi.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.n_cores)
plt.subplot(1,2,2)
df.n_cores.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.sc_h)
plt.subplot(1,2,2)
df.sc_h.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.sc_w)
plt.subplot(1,2,2)
df.sc_w.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.countplot(data=df,x=df.price_range)
plt.subplot(1,2,2)
df.price_range.value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()
